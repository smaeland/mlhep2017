# %% [markdown]
# ### Face completion
#
# You get the left half of a face image. Predict the right one.

# %%
from __future__ import print_function
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.datasets import fetch_olivetti_faces
data = fetch_olivetti_faces().images
# Out:
# downloading Olivetti faces from http://cs.nyu.edu/~roweis/data/olivettifaces.mat to /root/scikit_learn_data

# %%
#Yet another matplotlib feature - subplot - creates a grid-like structure of plots
#Syntax: plt.subplot(width,height,index) with index starting from 1.
plt.subplot(2,2,1)
plt.imshow(data[0],cmap='gray')
plt.subplot(2,2,2)
plt.imshow(data[1],cmap='gray')
plt.subplot(2,2,3)
plt.imshow(data[2],cmap='gray')
plt.subplot(2,2,4)
plt.imshow(data[3],cmap='gray')

# %%
plt.imshow(data[:,:,:32][0], cmap='gray')

# %% [markdown]
# # X,y
#
# We now must slice the data into known part "X" and unknown part "y". Since data is just a numpy array, you can slice it with multi-dimensional slices.
#
# The dimensions are (image_index, height, width).
#
# * `data[:10]` - first 10 images
# * `data[:, :10]` - 10-pixel stripe at the top of each image.
# * `data[10:20, :, :10]` - take images 10-19 and slice __horizontally__ a stripe of width 10 pixels
#
# Let's now use that to slice our data.

# %%
X = data[:,:,:32]
y = data[:,:,32:]

# %%
#If you did everything right, you should see two half-faces composing a face
plt.subplot(1,2,1)
plt.imshow(X[0],cmap='gray')
plt.subplot(1,2,2)
plt.imshow(y[0],cmap='gray')

# %%
def glue(left_half,right_half):
    #melt two half-faces back into a face
    left_half = left_half.reshape([-1,64,32])
    right_half = right_half.reshape([-1,64,32])
    return np.concatenate([left_half,right_half],axis=-1)


plt.imshow(glue(X,y)[99],cmap='gray')

# %% [markdown]
# # Linear Regression
#
# Now let's get through the usual pipeline: split data between train and test; fit linear regression

# %%
from sklearn.cross_validation import train_test_split
X_train,X_test,Y_train,Y_test = train_test_split(X.reshape([len(X),-1]),
                                                 y.reshape([len(y),-1]),
                                                 test_size=0.05,random_state=42)
print("X_train.shape=",X_train.shape)
print("X_test.shape=",X_test.shape)
# Out:
# X_train.shape= (380, 2048)
# X_test.shape= (20, 2048)
# /opt/conda/lib/python3.6/site-packages/sklearn/cross_validation.py:44: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X_train,Y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
from sklearn.metrics import mean_squared_error

print (mean_squared_error(Y_train, model.predict(X_train)))
print (mean_squared_error(Y_test, model.predict(X_test)))
# Out:
# 3.07376358436e-12
# 0.0102836980291

# %%
#Images restored on the training settrain

predictions = model.predict(X_train)

pics = glue(X_train, predictions)
plt.figure(figsize=[16,12])
for i in range(20):
    plt.subplot(4,5,i+1)
    plt.imshow(pics[i],cmap='gray')

# %%
#Images from test restored
predictions = model.predict(X_test)

pics = glue(X_test,predictions)
plt.figure(figsize=[16,12])
for i in range(20):
    plt.subplot(4,5,i+1)
    plt.imshow(pics[i],cmap='gray')

# %% [markdown]
# # Ridge regression
#
# Ridge regression is a simple linear regression with L2 penalty: $ argmin \space L + \alpha \cdot \sum_i W_i^2 $

# %%
from sklearn.linear_model import Ridge

#Example syntax: Ridge(alpha=0.5), just like LinearRegression

# %%
from sklearn.linear_model import Ridge
ridgemodel = Ridge(alpha=0.5)
ridgemodel.fit(X_train, Y_train)
# Out:
# Ridge(alpha=0.5, copy_X=True, fit_intercept=True, max_iter=None,
#    normalize=False, random_state=None, solver='auto', tol=0.001)

# %%
print (mean_squared_error(Y_train, ridgemodel.predict(X_train)))
print (mean_squared_error(Y_test, ridgemodel.predict(X_test)))
# Out:
# 0.000423059558831
# 0.00802960325088

# %%
#Images from test restored
predictions = ridgemodel.predict(X_test)

pics = glue(X_test,predictions)
plt.figure(figsize=[16,12])
for i in range(20):
    plt.subplot(4,5,i+1)
    plt.imshow(pics[i],cmap='gray')

# %% [markdown]
# # Bonus: Grid search
#
# Find alpha that minimizes test error. You can do so by enumerating all alphas in a reasonable diapason using loops.

# %%
#alphas = np.logspace(-3, 7, 10)
alphas = np.linspace(0.01, 10, 20)
print ("alphas:", alphas)
# Out:
# alphas: [  0.01         0.53578947   1.06157895   1.58736842   2.11315789
#    2.63894737   3.16473684   3.69052632   4.21631579   4.74210526
#    5.26789474   5.79368421   6.31947368   6.84526316   7.37105263
#    7.89684211   8.42263158   8.94842105   9.47421053  10.        ]

# %%
for a in alphas:
    ridgemodel.alpha = a
    ridgemodel.fit(X_train, Y_train)
    print ("alpha = {:3e}, test loss = {}".format(a, mean_squared_error(Y_test, ridgemodel.predict(X_test))))
# Out:
# alpha = 1.000000e-02, test loss = 0.010137250001463968
# alpha = 5.357895e-01, test loss = 0.007973299786820431
# alpha = 1.061579e+00, test loss = 0.0074753101822344105
# alpha = 1.587368e+00, test loss = 0.007257860731165897
# alpha = 2.113158e+00, test loss = 0.007149664248060735
# alpha = 2.638947e+00, test loss = 0.007096329557404907
# alpha = 3.164737e+00, test loss = 0.007074360794463389
# alpha = 3.690526e+00, test loss = 0.0070717667789095
# alpha = 4.216316e+00, test loss = 0.007081747856355748
# alpha = 4.742105e+00, test loss = 0.007100158819716826
# alpha = 5.267895e+00, test loss = 0.007124336482769082
# alpha = 5.793684e+00, test loss = 0.007152500857669671
# alpha = 6.319474e+00, test loss = 0.0071834253837938546
# alpha = 6.845263e+00, test loss = 0.0072162443464084125
# alpha = 7.371053e+00, test loss = 0.007250335001743256
# alpha = 7.896842e+00, test loss = 0.007285242601207644
# alpha = 8.422632e+00, test loss = 0.007320631151506422
# alpha = 8.948421e+00, test loss = 0.007356250190670005
# alpha = 9.474211e+00, test loss = 0.00739191184648394
# alpha = 1.000000e+01, test loss = 0.0074274746756025035
